# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import time
from io import StringIO
import random
from fake_useragent import UserAgent

# Initialize a UserAgent instance for random User-Agent headers
ua = UserAgent()

# Function to introduce randomized delays
def randomized_delay(min_delay=1, max_delay=5):
    delay = random.uniform(min_delay, max_delay)
    print(f"Delaying for {delay:.2f} seconds...")
    time.sleep(delay)

# Enhanced fetch function
def fetch_with_backoff(url, retries=5, min_delay=1, max_delay=5, long_wait=3600, use_proxy=False):
    session = requests.Session()
    headers = {
        "User-Agent": ua.random,
        "Accept-Language": "en-US,en;q=0.9",
        "Accept-Encoding": "gzip, deflate, br",
        "Connection": "keep-alive",
        "Referer": "https://www.google.com/"
    }
    
    proxies = {
        "http": "http://your_proxy:port",
        "https": "https://your_proxy:port"
    } if use_proxy else None

    for attempt in range(retries):
        try:
            response = session.get(url, headers=headers, proxies=proxies, timeout=10)
            if response.status_code == 200:
                return response
            elif response.status_code in [429, 500]:
                print(f"Rate limit or server error. Retrying in {min_delay} to {max_delay} seconds (Attempt {attempt + 1}/{retries})...")
                randomized_delay(min_delay, max_delay)
            else:
                print(f"Unexpected status code {response.status_code} for URL: {url}")
                break
        except requests.exceptions.RequestException as e:
            print(f"Request failed: {e}. Retrying...")
            randomized_delay(min_delay, max_delay)

    print(f"Max retries reached. Waiting for {long_wait} seconds before one final retry...")
    time.sleep(long_wait)
    try:
        response = session.get(url, headers=headers, proxies=proxies, timeout=10)
        if response.status_code == 200:
            return response
        else:
            print(f"Final attempt failed with status code {response.status_code} for URL: {url}")
    except requests.exceptions.RequestException as e:
        print(f"Final request failed: {e}")

    return None

# Function to scrape Premier League data
def scrape_premier_league(seasons):
    print("Starting scrape_premier_league function...")
    all_matches = []

    for season in seasons:
        print(f"Scraping data for season: {season}")
        standings_url = f"https://fbref.com/en/comps/9/{season}/Premier-League-Stats"
        response = fetch_with_backoff(standings_url)
        if not response:
            print(f"Failed to fetch standings page for season {season}.")
            continue

        soup = BeautifulSoup(response.text, 'html.parser')
        standings_table = soup.select_one('table.stats_table')
        if not standings_table:
            print(f"Standings table not found on page for season {season}.")
            continue

        team_links = [a['href'] for a in standings_table.find_all('a', href=True) if '/squads/' in a['href']]
        team_urls = [f"https://fbref.com{link}" for link in team_links]

        for team_url in team_urls:
            print(f"Fetching data from: {team_url}")
            team_response = fetch_with_backoff(team_url)
            if not team_response:
                print(f"Skipping team due to repeated failures: {team_url}")
                continue

            team_soup = BeautifulSoup(team_response.text, 'html.parser')
            team_name = team_soup.select_one("h1").text.split(" Stats")[0]  # Extract team name
            print(f"Processing team: {team_name}")

            try:
                matches = pd.read_html(StringIO(team_response.text), match="Scores & Fixtures")[0]
            except ValueError:
                print(f"No 'Scores & Fixtures' table found for {team_url}. Skipping...")
                continue

            matches = matches[matches["Comp"] == "Premier League"]

            shooting_links = [a['href'] for a in team_soup.find_all('a', href=True) if 'all_comps/shooting/' in a['href']]
            if not shooting_links:
                print(f"No shooting stats link found for {team_url}. Skipping shooting data...")
                continue

            shooting_url = f"https://fbref.com{shooting_links[0]}"
            shooting_response = fetch_with_backoff(shooting_url)
            if not shooting_response:
                print(f"Skipping shooting data due to repeated failures: {shooting_url}")
                continue

            try:
                shooting = pd.read_html(StringIO(shooting_response.text), match="Shooting")[0]
            except ValueError:
                print(f"No 'Shooting' table found at {shooting_url}. Skipping...")
                continue

            shooting.columns = shooting.columns.droplevel()

            try:
                team_data = matches.merge(
                    shooting[["Date", "Sh", "SoT", "Dist", "FK", "PK", "PKatt"]],
                    on="Date"
                )
            except ValueError:
                print(f"Error merging match and shooting data for {team_url}. Skipping...")
                continue

            team_data["Season"] = season
            team_data["Team"] = team_name
            all_matches.append(team_data)
            print(f"Data collected for {len(team_data)} matches for {team_name}.")

            randomized_delay()

    if all_matches:
        match_df = pd.concat(all_matches, ignore_index=True)
        match_df.columns = [c.lower() for c in match_df.columns]  # Standardize column names
        print(f"Data collected for {len(match_df)} matches across all teams.")
        match_df.to_csv("matches.csv", index=False)
    else:
        print("No match data collected.")

    print("Scraping complete!")

# Specify the seasons you want to scrape
seasons_to_scrape = ["2021-2022", "2022-2023", "2023-2024", "2024-2025"]

# Run the scraping function
scrape_premier_league(seasons_to_scrape)
# Out:
# Starting scrape_premier_league function...
# Scraping data for season: 2021-2022
# Fetching data from: https://fbref.com/en/squads/b8fd03ef/2021-2022/Manchester-City-Stats
# Processing team:
# 2021-2022 Manchester City
# Data collected for 38 matches for
# 2021-2022 Manchester City.
# Delaying for 1.73 seconds...
# Fetching data from: https://fbref.com/en/squads/822bd0ba/2021-2022/Liverpool-Stats
# Processing team:
# 2021-2022 Liverpool
# Data collected for 38 matches for
# 2021-2022 Liverpool.
# Delaying for 2.59 seconds...
# Fetching data from: https://fbref.com/en/squads/cff3d9bb/2021-2022/Chelsea-Stats
# Processing team:
# 2021-2022 Chelsea
# Data collected for 38 matches for
# 2021-2022 Chelsea.
# Delaying for 2.86 seconds...
# Fetching data from: https://fbref.com/en/squads/361ca564/2021-2022/Tottenham-Hotspur-Stats
# Processing team:
# 2021-2022 Tottenham Hotspur
# Data collected for 38 matches for
# 2021-2022 Tottenham Hotspur.
# Delaying for 1.63 seconds...
# Fetching data from: https://fbref.com/en/squads/18bb7c10/2021-2022/Arsenal-Stats
# Processing team:
# 2021-2022 Arsenal
# Data collected for 38 matches for
# 2021-2022 Arsenal.
# Delaying for 3.69 seconds...
# Fetching data from: https://fbref.com/en/squads/19538871/2021-2022/Manchester-United-Stats
# Processing team:
# 2021-2022 Manchester United
# Data collected for 38 matches for
# 2021-2022 Manchester United.
# Delaying for 4.41 seconds...
# Fetching data from: https://fbref.com/en/squads/7c21e445/2021-2022/West-Ham-United-Stats
# Processing team:
# 2021-2022 West Ham United
# Data collected for 38 matches for
# 2021-2022 West Ham United.
# Delaying for 2.60 seconds...
# Fetching data from: https://fbref.com/en/squads/a2d435b3/2021-2022/Leicester-City-Stats
# Processing team:
# 2021-2022 Leicester City
# Data collected for 38 matches for
# 2021-2022 Leicester City.
# Delaying for 1.68 seconds...
# Fetching data from: https://fbref.com/en/squads/d07537b9/2021-2022/Brighton-and-Hove-Albion-Stats
# Processing team:
# 2021-2022 Brighton & Hove Albion
# Data collected for 38 matches for
# 2021-2022 Brighton & Hove Albion.
# Delaying for 4.47 seconds...
# Fetching data from: https://fbref.com/en/squads/8cec06e1/2021-2022/Wolverhampton-Wanderers-Stats
# Rate limit or server error. Retrying in 1 to 5 seconds (Attempt 1/5)...
# Delaying for 1.58 seconds...
# Rate limit or server error. Retrying in 1 to 5 seconds (Attempt 2/5)...
# Delaying for 3.35 seconds...
# Rate limit or server error. Retrying in 1 to 5 seconds (Attempt 3/5)...
# Delaying for 1.69 seconds...
# Rate limit or server error. Retrying in 1 to 5 seconds (Attempt 4/5)...
# Delaying for 3.23 seconds...
# Rate limit or server error. Retrying in 1 to 5 seconds (Attempt 5/5)...
# Delaying for 2.56 seconds...
# Max retries reached. Waiting for 3600 seconds before one final retry...
# Processing team:
# 2021-2022 Wolverhampton Wanderers
# Data collected for 38 matches for
# 2021-2022 Wolverhampton Wanderers.
# Delaying for 1.20 seconds...
# Fetching data from: https://fbref.com/en/squads/b2b47a98/2021-2022/Newcastle-United-Stats
# Processing team:
# 2021-2022 Newcastle United
# Data collected for 38 matches for
# 2021-2022 Newcastle United.
# Delaying for 2.99 seconds...
# Fetching data from: https://fbref.com/en/squads/47c64c55/2021-2022/Crystal-Palace-Stats
# Processing team:
# 2021-2022 Crystal Palace
# Data collected for 38 matches for
# 2021-2022 Crystal Palace.
# Delaying for 2.34 seconds...
# Fetching data from: https://fbref.com/en/squads/cd051869/2021-2022/Brentford-Stats
# Processing team:
# 2021-2022 Brentford
# Data collected for 38 matches for
# 2021-2022 Brentford.
# Delaying for 4.37 seconds...
# Fetching data from: https://fbref.com/en/squads/8602292d/2021-2022/Aston-Villa-Stats
# Processing team:
# 2021-2022 Aston Villa
# Data collected for 38 matches for
# 2021-2022 Aston Villa.
# Delaying for 2.90 seconds...
# Fetching data from: https://fbref.com/en/squads/33c895d4/2021-2022/Southampton-Stats
# Processing team:
# 2021-2022 Southampton
# Data collected for 38 matches for
# 2021-2022 Southampton.
# Delaying for 2.26 seconds...
# Fetching data from: https://fbref.com/en/squads/d3fd31cc/2021-2022/Everton-Stats
# Processing team:
# 2021-2022 Everton
# Data collected for 38 matches for
# 2021-2022 Everton.
# Delaying for 2.84 seconds...
# Fetching data from: https://fbref.com/en/squads/5bfb9659/2021-2022/Leeds-United-Stats
# Processing team:
# 2021-2022 Leeds United
# Data collected for 38 matches for
# 2021-2022 Leeds United.
# Delaying for 2.54 seconds...
# Fetching data from: https://fbref.com/en/squads/943e8050/2021-2022/Burnley-Stats
# Processing team:
# 2021-2022 Burnley
# Data collected for 38 matches for
# 2021-2022 Burnley.
# Delaying for 4.80 seconds...
# Fetching data from: https://fbref.com/en/squads/2abfe087/2021-2022/Watford-Stats
# Processing team:
# 2021-2022 Watford
# Data collected for 38 matches for
# 2021-2022 Watford.
# Delaying for 1.23 seconds...
# Fetching data from: https://fbref.com/en/squads/1c781004/2021-2022/Norwich-City-Stats
# Processing team:
# 2021-2022 Norwich City
# Data collected for 38 matches for
# 2021-2022 Norwich City.
# Delaying for 4.49 seconds...
# Scraping data for season: 2022-2023
# Fetching data from: https://fbref.com/en/squads/b8fd03ef/2022-2023/Manchester-City-Stats
# Processing team:
# 2022-2023 Manchester City
# Data collected for 38 matches for
# 2022-2023 Manchester City.
# Delaying for 2.94 seconds...
# Fetching data from: https://fbref.com/en/squads/18bb7c10/2022-2023/Arsenal-Stats
# Processing team:
# 2022-2023 Arsenal
# Data collected for 38 matches for
# 2022-2023 Arsenal.
# Delaying for 4.11 seconds...
# Fetching data from: https://fbref.com/en/squads/19538871/2022-2023/Manchester-United-Stats
# Processing team:
# 2022-2023 Manchester United
# Data collected for 38 matches for
# 2022-2023 Manchester United.
# Delaying for 3.60 seconds...
# Fetching data from: https://fbref.com/en/squads/b2b47a98/2022-2023/Newcastle-United-Stats
# Processing team:
# 2022-2023 Newcastle United
# Data collected for 38 matches for
# 2022-2023 Newcastle United.
# Delaying for 2.27 seconds...
# Fetching data from: https://fbref.com/en/squads/822bd0ba/2022-2023/Liverpool-Stats
# Processing team:
# 2022-2023 Liverpool
# Data collected for 38 matches for
# 2022-2023 Liverpool.
# Delaying for 3.87 seconds...
# Fetching data from: https://fbref.com/en/squads/d07537b9/2022-2023/Brighton-and-Hove-Albion-Stats
# Processing team:
# 2022-2023 Brighton & Hove Albion
# Data collected for 38 matches for
# 2022-2023 Brighton & Hove Albion.
# Delaying for 4.16 seconds...
# Fetching data from: https://fbref.com/en/squads/8602292d/2022-2023/Aston-Villa-Stats
# Processing team:
# 2022-2023 Aston Villa
# Data collected for 38 matches for
# 2022-2023 Aston Villa.
# Delaying for 3.38 seconds...
# Fetching data from: https://fbref.com/en/squads/361ca564/2022-2023/Tottenham-Hotspur-Stats
# Processing team:
# 2022-2023 Tottenham Hotspur
# Data collected for 38 matches for
# 2022-2023 Tottenham Hotspur.
# Delaying for 4.19 seconds...
# Fetching data from: https://fbref.com/en/squads/cd051869/2022-2023/Brentford-Stats
# Processing team:
# 2022-2023 Brentford
# Data collected for 38 matches for
# 2022-2023 Brentford.
# Delaying for 3.73 seconds...
# Fetching data from: https://fbref.com/en/squads/fd962109/2022-2023/Fulham-Stats
# Processing team:
# 2022-2023 Fulham
# Data collected for 38 matches for
# 2022-2023 Fulham.
# Delaying for 1.88 seconds...
# Fetching data from: https://fbref.com/en/squads/47c64c55/2022-2023/Crystal-Palace-Stats
# Processing team:
# 2022-2023 Crystal Palace
# Data collected for 38 matches for
# 2022-2023 Crystal Palace.
# Delaying for 1.59 seconds...
# Fetching data from: https://fbref.com/en/squads/cff3d9bb/2022-2023/Chelsea-Stats
# Processing team:
# 2022-2023 Chelsea
# Data collected for 38 matches for
# 2022-2023 Chelsea.
# Delaying for 1.06 seconds...
# Fetching data from: https://fbref.com/en/squads/8cec06e1/2022-2023/Wolverhampton-Wanderers-Stats
# Processing team:
# 2022-2023 Wolverhampton Wanderers
# Data collected for 38 matches for
# 2022-2023 Wolverhampton Wanderers.
# Delaying for 2.04 seconds...
# Fetching data from: https://fbref.com/en/squads/7c21e445/2022-2023/West-Ham-United-Stats
# Processing team:
# 2022-2023 West Ham United
# Data collected for 38 matches for
# 2022-2023 West Ham United.
# Delaying for 4.60 seconds...
# Fetching data from: https://fbref.com/en/squads/4ba7cbea/2022-2023/Bournemouth-Stats
# Processing team:
# 2022-2023 Bournemouth
# Data collected for 38 matches for
# 2022-2023 Bournemouth.
# Delaying for 2.56 seconds...
# Fetching data from: https://fbref.com/en/squads/e4a775cb/2022-2023/Nottingham-Forest-Stats
# Processing team:
# 2022-2023 Nottingham Forest
# Data collected for 38 matches for
# 2022-2023 Nottingham Forest.
# Delaying for 3.45 seconds...
# Fetching data from: https://fbref.com/en/squads/d3fd31cc/2022-2023/Everton-Stats
# Processing team:
# 2022-2023 Everton
# Data collected for 38 matches for
# 2022-2023 Everton.
# Delaying for 1.46 seconds...
# Fetching data from: https://fbref.com/en/squads/a2d435b3/2022-2023/Leicester-City-Stats
# Processing team:
# 2022-2023 Leicester City
# Data collected for 38 matches for
# 2022-2023 Leicester City.
# Delaying for 2.41 seconds...
# Fetching data from: https://fbref.com/en/squads/5bfb9659/2022-2023/Leeds-United-Stats
# Processing team:
# 2022-2023 Leeds United
# Data collected for 38 matches for
# 2022-2023 Leeds United.
# Delaying for 3.86 seconds...
# Fetching data from: https://fbref.com/en/squads/33c895d4/2022-2023/Southampton-Stats
# Processing team:
# 2022-2023 Southampton
# Data collected for 38 matches for
# 2022-2023 Southampton.
# Delaying for 2.82 seconds...
# Scraping data for season: 2023-2024
# Fetching data from: https://fbref.com/en/squads/b8fd03ef/2023-2024/Manchester-City-Stats
# Processing team:
# 2023-2024 Manchester City
# Data collected for 38 matches for
# 2023-2024 Manchester City.
# Delaying for 4.56 seconds...
# Fetching data from: https://fbref.com/en/squads/18bb7c10/2023-2024/Arsenal-Stats
# Processing team:
# 2023-2024 Arsenal
# Data collected for 38 matches for
# 2023-2024 Arsenal.
# Delaying for 1.51 seconds...
# Fetching data from: https://fbref.com/en/squads/822bd0ba/2023-2024/Liverpool-Stats
# Processing team:
# 2023-2024 Liverpool
# Data collected for 38 matches for
# 2023-2024 Liverpool.
# Delaying for 3.84 seconds...
# Fetching data from: https://fbref.com/en/squads/8602292d/2023-2024/Aston-Villa-Stats
# Processing team:
# 2023-2024 Aston Villa
# Data collected for 38 matches for
# 2023-2024 Aston Villa.
# Delaying for 4.65 seconds...
# Fetching data from: https://fbref.com/en/squads/361ca564/2023-2024/Tottenham-Hotspur-Stats
# Processing team:
# 2023-2024 Tottenham Hotspur
# Data collected for 38 matches for
# 2023-2024 Tottenham Hotspur.
# Delaying for 4.75 seconds...
# Fetching data from: https://fbref.com/en/squads/cff3d9bb/2023-2024/Chelsea-Stats
# Processing team:
# 2023-2024 Chelsea
# Data collected for 38 matches for
# 2023-2024 Chelsea.
# Delaying for 2.96 seconds...
# Fetching data from: https://fbref.com/en/squads/b2b47a98/2023-2024/Newcastle-United-Stats
# Processing team:
# 2023-2024 Newcastle United
# Data collected for 38 matches for
# 2023-2024 Newcastle United.
# Delaying for 2.40 seconds...
# Fetching data from: https://fbref.com/en/squads/19538871/2023-2024/Manchester-United-Stats
# Processing team:
# 2023-2024 Manchester United
# Data collected for 38 matches for
# 2023-2024 Manchester United.
# Delaying for 4.98 seconds...
# Fetching data from: https://fbref.com/en/squads/7c21e445/2023-2024/West-Ham-United-Stats
# Processing team:
# 2023-2024 West Ham United
# Data collected for 38 matches for
# 2023-2024 West Ham United.
# Delaying for 1.53 seconds...
# Fetching data from: https://fbref.com/en/squads/47c64c55/2023-2024/Crystal-Palace-Stats
# Processing team:
# 2023-2024 Crystal Palace
# Rate limit or server error. Retrying in 1 to 5 seconds (Attempt 1/5)...
# Delaying for 4.32 seconds...
# Rate limit or server error. Retrying in 1 to 5 seconds (Attempt 2/5)...
# Delaying for 4.58 seconds...
# Rate limit or server error. Retrying in 1 to 5 seconds (Attempt 3/5)...
# Delaying for 1.44 seconds...
# Rate limit or server error. Retrying in 1 to 5 seconds (Attempt 4/5)...
# Delaying for 1.48 seconds...
# Rate limit or server error. Retrying in 1 to 5 seconds (Attempt 5/5)...
# Delaying for 2.62 seconds...
# Max retries reached. Waiting for 3600 seconds before one final retry...
# Data collected for 38 matches for
# 2023-2024 Crystal Palace.
# Delaying for 1.57 seconds...
# Fetching data from: https://fbref.com/en/squads/d07537b9/2023-2024/Brighton-and-Hove-Albion-Stats
# Processing team:
# 2023-2024 Brighton & Hove Albion
# Data collected for 38 matches for
# 2023-2024 Brighton & Hove Albion.
# Delaying for 3.79 seconds...
# Fetching data from: https://fbref.com/en/squads/4ba7cbea/2023-2024/Bournemouth-Stats
# Processing team:
# 2023-2024 Bournemouth
# Data collected for 38 matches for
# 2023-2024 Bournemouth.
# Delaying for 1.06 seconds...
# Fetching data from: https://fbref.com/en/squads/fd962109/2023-2024/Fulham-Stats
# Processing team:
# 2023-2024 Fulham
# Data collected for 38 matches for
# 2023-2024 Fulham.
# Delaying for 2.70 seconds...
# Fetching data from: https://fbref.com/en/squads/8cec06e1/2023-2024/Wolverhampton-Wanderers-Stats
# Processing team:
# 2023-2024 Wolverhampton Wanderers
# Data collected for 38 matches for
# 2023-2024 Wolverhampton Wanderers.
# Delaying for 3.46 seconds...
# Fetching data from: https://fbref.com/en/squads/d3fd31cc/2023-2024/Everton-Stats
# Processing team:
# 2023-2024 Everton
# Data collected for 38 matches for
# 2023-2024 Everton.
# Delaying for 1.67 seconds...
# Fetching data from: https://fbref.com/en/squads/cd051869/2023-2024/Brentford-Stats
# Processing team:
# 2023-2024 Brentford
# Data collected for 38 matches for
# 2023-2024 Brentford.
# Delaying for 3.49 seconds...
# Fetching data from: https://fbref.com/en/squads/e4a775cb/2023-2024/Nottingham-Forest-Stats
# Processing team:
# 2023-2024 Nottingham Forest
# Data collected for 38 matches for
# 2023-2024 Nottingham Forest.
# Delaying for 3.91 seconds...
# Fetching data from: https://fbref.com/en/squads/e297cd13/2023-2024/Luton-Town-Stats
# Processing team:
# 2023-2024 Luton Town
# Data collected for 38 matches for
# 2023-2024 Luton Town.
# Delaying for 2.37 seconds...
# Fetching data from: https://fbref.com/en/squads/943e8050/2023-2024/Burnley-Stats
# Processing team:
# 2023-2024 Burnley
# Data collected for 38 matches for
# 2023-2024 Burnley.
# Delaying for 2.18 seconds...
# Fetching data from: https://fbref.com/en/squads/1df6b87e/2023-2024/Sheffield-United-Stats
# Processing team:
# 2023-2024 Sheffield United
# Data collected for 38 matches for
# 2023-2024 Sheffield United.
# Delaying for 2.54 seconds...
# Scraping data for season: 2024-2025
# Rate limit or server error. Retrying in 1 to 5 seconds (Attempt 1/5)...
# Delaying for 2.93 seconds...
# Rate limit or server error. Retrying in 1 to 5 seconds (Attempt 2/5)...
# Delaying for 4.81 seconds...
# Rate limit or server error. Retrying in 1 to 5 seconds (Attempt 3/5)...
# Delaying for 4.83 seconds...
# Rate limit or server error. Retrying in 1 to 5 seconds (Attempt 4/5)...
# Delaying for 3.16 seconds...
# Rate limit or server error. Retrying in 1 to 5 seconds (Attempt 5/5)...
# Delaying for 1.71 seconds...
# Max retries reached. Waiting for 3600 seconds before one final retry...
# Fetching data from: https://fbref.com/en/squads/822bd0ba/Liverpool-Stats
# Processing team:
# 2024-2025 Liverpool
# Data collected for 18 matches for
# 2024-2025 Liverpool.
# Delaying for 2.83 seconds...
# Fetching data from: https://fbref.com/en/squads/18bb7c10/Arsenal-Stats
# Processing team:
# 2024-2025 Arsenal
# Data collected for 19 matches for
# 2024-2025 Arsenal.
# Delaying for 3.28 seconds...
# Fetching data from: https://fbref.com/en/squads/e4a775cb/Nottingham-Forest-Stats
# Processing team:
# 2024-2025 Nottingham Forest
# Data collected for 19 matches for
# 2024-2025 Nottingham Forest.
# Delaying for 4.36 seconds...
# Fetching data from: https://fbref.com/en/squads/cff3d9bb/Chelsea-Stats
# Processing team:
# 2024-2025 Chelsea
# Data collected for 19 matches for
# 2024-2025 Chelsea.
# Delaying for 4.55 seconds...
# Fetching data from: https://fbref.com/en/squads/b2b47a98/Newcastle-United-Stats
# Processing team:
# 2024-2025 Newcastle United
# Data collected for 19 matches for
# 2024-2025 Newcastle United.
# Delaying for 1.50 seconds...
# Fetching data from: https://fbref.com/en/squads/b8fd03ef/Manchester-City-Stats
# Processing team:
# 2024-2025 Manchester City
# Data collected for 19 matches for
# 2024-2025 Manchester City.
# Delaying for 2.14 seconds...
# Fetching data from: https://fbref.com/en/squads/4ba7cbea/Bournemouth-Stats
# Processing team:
# 2024-2025 Bournemouth
# Rate limit or server error. Retrying in 1 to 5 seconds (Attempt 1/5)...
# Delaying for 1.30 seconds...
# Rate limit or server error. Retrying in 1 to 5 seconds (Attempt 2/5)...
# Delaying for 3.77 seconds...
# Rate limit or server error. Retrying in 1 to 5 seconds (Attempt 3/5)...
# Delaying for 3.07 seconds...
# Rate limit or server error. Retrying in 1 to 5 seconds (Attempt 4/5)...
# Delaying for 3.63 seconds...
# Rate limit or server error. Retrying in 1 to 5 seconds (Attempt 5/5)...
# Delaying for 4.95 seconds...
# Max retries reached. Waiting for 3600 seconds before one final retry...
# Data collected for 19 matches for
# 2024-2025 Bournemouth.
# Delaying for 2.39 seconds...
# Fetching data from: https://fbref.com/en/squads/fd962109/Fulham-Stats
# Processing team:
# 2024-2025 Fulham
# Data collected for 19 matches for
# 2024-2025 Fulham.
# Delaying for 2.69 seconds...
# Fetching data from: https://fbref.com/en/squads/8602292d/Aston-Villa-Stats
# Processing team:
# 2024-2025 Aston Villa
# Data collected for 19 matches for
# 2024-2025 Aston Villa.
# Delaying for 4.65 seconds...
# Fetching data from: https://fbref.com/en/squads/d07537b9/Brighton-and-Hove-Albion-Stats
# Processing team:
# 2024-2025 Brighton & Hove Albion
# Data collected for 19 matches for
# 2024-2025 Brighton & Hove Albion.
# Delaying for 3.11 seconds...
# Fetching data from: https://fbref.com/en/squads/361ca564/Tottenham-Hotspur-Stats
# Processing team:
# 2024-2025 Tottenham Hotspur
# Data collected for 19 matches for
# 2024-2025 Tottenham Hotspur.
# Delaying for 2.17 seconds...
# Fetching data from: https://fbref.com/en/squads/cd051869/Brentford-Stats
# Processing team:
# 2024-2025 Brentford
# Data collected for 19 matches for
# 2024-2025 Brentford.
# Delaying for 4.07 seconds...
# Fetching data from: https://fbref.com/en/squads/7c21e445/West-Ham-United-Stats
# Processing team:
# 2024-2025 West Ham United
# Data collected for 19 matches for
# 2024-2025 West Ham United.
# Delaying for 2.24 seconds...
# Fetching data from: https://fbref.com/en/squads/19538871/Manchester-United-Stats
# Processing team:
# 2024-2025 Manchester United
# Data collected for 19 matches for
# 2024-2025 Manchester United.
# Delaying for 3.69 seconds...
# Fetching data from: https://fbref.com/en/squads/47c64c55/Crystal-Palace-Stats
# Processing team:
# 2024-2025 Crystal Palace
# Data collected for 19 matches for
# 2024-2025 Crystal Palace.
# Delaying for 3.82 seconds...
# Fetching data from: https://fbref.com/en/squads/d3fd31cc/Everton-Stats
# Processing team:
# 2024-2025 Everton
# Data collected for 18 matches for
# 2024-2025 Everton.
# Delaying for 2.18 seconds...
# Fetching data from: https://fbref.com/en/squads/8cec06e1/Wolverhampton-Wanderers-Stats
# Processing team:
# 2024-2025 Wolverhampton Wanderers
# Rate limit or server error. Retrying in 1 to 5 seconds (Attempt 1/5)...
# Delaying for 2.07 seconds...
# Rate limit or server error. Retrying in 1 to 5 seconds (Attempt 2/5)...
# Delaying for 3.36 seconds...
# Rate limit or server error. Retrying in 1 to 5 seconds (Attempt 3/5)...
# Delaying for 4.74 seconds...
# Rate limit or server error. Retrying in 1 to 5 seconds (Attempt 4/5)...
# Delaying for 3.87 seconds...
# Rate limit or server error. Retrying in 1 to 5 seconds (Attempt 5/5)...
# Delaying for 1.70 seconds...
# Max retries reached. Waiting for 3600 seconds before one final retry...
# Data collected for 19 matches for
# 2024-2025 Wolverhampton Wanderers.
# Delaying for 2.05 seconds...
# Fetching data from: https://fbref.com/en/squads/b74092de/Ipswich-Town-Stats
# Processing team:
# 2024-2025 Ipswich Town
# Data collected for 19 matches for
# 2024-2025 Ipswich Town.
# Delaying for 1.26 seconds...
# Fetching data from: https://fbref.com/en/squads/a2d435b3/Leicester-City-Stats
# Processing team:
# 2024-2025 Leicester City
# Data collected for 19 matches for
# 2024-2025 Leicester City.
# Delaying for 3.82 seconds...
# Fetching data from: https://fbref.com/en/squads/33c895d4/Southampton-Stats
# Processing team:
# 2024-2025 Southampton
# Data collected for 19 matches for
# 2024-2025 Southampton.
# Delaying for 2.28 seconds...
# Data collected for 2658 matches across all teams.
# Scraping complete!

# %%
from IPython.display import FileLink

# Display a download link for the CSV file
FileLink('matches.csv')
# Out:
# /Users/tiki/matches.csv

# %%
matches
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 matches
#
# NameError: name 'matches' is not defined
